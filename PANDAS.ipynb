# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape #attribute
# Out:
# (88883, 85)

# %%
df.info() #method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(12)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(1)
# Out:
#        Respondent MainBranch Hobbyist              OpenSourcer  \
# 88882       88863        NaN      Yes  Less than once per year
#
#                                               OpenSource  \
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment Country         Student  \
# 88882  Not employed, and not looking for work   Spain  Yes, full-time
#
#                                   EdLevel  \
# 88882  Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther OrgSize DevType  \
# 88882  Taken an online course in programming or softw...     NaN     NaN
#
#       YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 88882         8         11            3       NaN    NaN      NaN      NaN
#
# ...

# %%
people={
    'first':['Corey','Jane','John'],
    'last':['Schafer','Doe','Doe'],
    'email':['coreymschafer@gmail.com','janedoe@gmail.com','johndoe@gamil.com']
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John      Doe        johndoe@gamil.com

# %%
df['email']
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@gmail.com
# 2          johndoe@gamil.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@gmail.com
# 2          johndoe@gamil.com
# Name: email, dtype: object

# %%
df[['last','email']]
# Out:
#       last                    email
# 0  Schafer  coreymschafer@gmail.com
# 1      Doe        janedoe@gmail.com
# 2      Doe        johndoe@gamil.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    coreymschafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1],[0,1]]
#df.iloc[[rows],[column]]
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe

# %%
df.loc[[0,1],['email','last']]
# Out:
#                      email     last
# 0  coreymschafer@gmail.com  Schafer
# 1        janedoe@gmail.com      Doe

# %%
df=pd.read_csv('survey_results_public.csv',index_col='Respondent')
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:2,'hobbyist']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[0:2,'Hobbyist':'Employment']

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 schema_df
#
# NameError: name 'schema_df' is not defined

# %%
print(schema_df.loc['MgrIdiot'])
print(schema_df.loc['MgrIdiot','QuestionText'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 print(schema_df.loc['MgrIdiot'])
#       2 print(schema_df.loc['MgrIdiot','QuestionText'])
#
# NameError: name 'schema_df' is not defined

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
schema_df.sort_index(ascending=False,inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
filt=(df['Country']=='India')

# %%
df[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df.loc[filt,'MgrIdiot']
# Out:
# Respondent
# 8                       NaN
# 10       Somewhat confident
# 15                      NaN
# 50           Very confident
# 65           Very confident
#                 ...
# 77339    Somewhat confident
# 79795    Somewhat confident
# 83862        Very confident
# 84299                   NaN
# 86012    Somewhat confident
# Name: MgrIdiot, Length: 9061, dtype: object

# %%
filt1=(df['Country']=='India') & (df['Hobbyist']=='No')

# %%
df.loc[filt1]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 78          I am a developer by profession       No
# 169         I am a developer by profession       No
# 220         I am a developer by profession       No
# 263         I am a developer by profession       No
# 291         I am a developer by profession       No
# ...                                    ...      ...
# 26419                                  NaN       No
# 40151                                  NaN       No
# 42599                                  NaN       No
# 50685                                  NaN       No
# 76822                                  NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 78          Less than once a month but more than once per ...
# 169                                   Less than once per year
# 220                                                     Never
# ...

# %%
df.loc[~filt1] #complement of filter
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
countries=['India','Hungaria','Pakistan']
filt2=df['Country'].isin(countries)

# %%
df.loc[filt2]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
# 88182                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
filt3=df['languageworkedwith'].str.contains('Python',na=False)

# %%
df.loc[filt3,'languageworkedwith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: languageworkedwith, Length: 36443, dtype: object

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df.columns
# Out:
# Index(['mainbranch', 'hobbyist', 'opensourcer', 'opensource', 'employment',
#        'country', 'student', 'edlevel', 'undergradmajor', 'eduother',
#        'orgsize', 'devtype', 'yearscode', 'age1stcode', 'yearscodepro',
#        'careersat', 'jobsat', 'mgridiot', 'mgrmoney', 'mgrwant', 'jobseek',
#        'lasthiredate', 'lastint', 'fizzbuzz', 'jobfactors', 'resumeupdate',
#        'currencysymbol', 'currencydesc', 'comptotal', 'compfreq',
#        'convertedcomp', 'workweekhrs', 'workplan', 'workchallenge',
#        'workremote', 'workloc', 'impsyn', 'coderev', 'coderevhrs', 'unittests',
#        'purchasehow', 'purchasewhat', 'languageworkedwith',
#        'languagedesirenextyear', 'databaseworkedwith',
#        'databasedesirenextyear', 'platformworkedwith',
#        'platformdesirenextyear', 'webframeworkedwith',
#        'webframedesirenextyear', 'misctechworkedwith',
#        'misctechdesirenextyear', 'devenviron', 'opsys', 'containers',
# ...

# %%
df['convertedcomp'].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: convertedcomp, dtype: float64

# %%
df.nlargest(10,'convertedcomp')
# Out:
#                                 mainbranch hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   opensourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %%
df.nsmallest(10,'convertedcomp')
# Out:
#                                 mainbranch hobbyist  \
# Respondent
# 280         I am a developer by profession      Yes
# 293         I am a developer by profession      Yes
# 722         I am a developer by profession       No
# 1105        I am a developer by profession       No
# 1501        I am a developer by profession      Yes
# 1685        I am a developer by profession      Yes
# 1782        I am a developer by profession      Yes
# 2019        I am a developer by profession       No
# 2095        I am a developer by profession      Yes
# 2665        I am a developer by profession      Yes
#
#                                                   opensourcer  \
# Respondent
# 280                                   Less than once per year
# 293                                   Less than once per year
# 722         Less than once a month but more than once per ...
# 1105                                                    Never
# ...

# %%
df['convertedcomp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: convertedcomp, dtype: float64

# %%
df['convertedcomp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\Kush Juvekar\AppData\Local\Temp\ipykernel_3768\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# comptotal        62000.0
# convertedcomp    57287.0
# workweekhrs         40.0
# coderevhrs           4.0
# age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           comptotal  convertedcomp   workweekhrs    coderevhrs           age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['convertedcomp'].count()
# Out:
# 55823

# %%
df['hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: hobbyist, Length: 88883, dtype: object

# %%
df['hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: hobbyist, dtype: int64

# %%
df['socialmedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: socialmedia, Length: 88883, dtype: object

# %%
df['socialmedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: socialmedia, dtype: int64

# %%
df['socialmedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: socialmedia, dtype: float64

# %%
#group by =split apply function combining

# %%
df['country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: country, Length: 179, dtype: int64

# %%
countrygroup=df.groupby('country')

# %%
countrygroup.get_group('India')
# Out:
#                                         mainbranch hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   opensourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
filt=df['country']=='United States'
df.loc[filt]['socialmedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: socialmedia, dtype: int64

# %%
filt=df['country']=='India'
df.loc[filt]['socialmedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: socialmedia, dtype: int64

# %%
countrygroup['socialmedia'].value_counts().head(50)
# Out:
# country              socialmedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
countrygroup['socialmedia'].value_counts().loc['Russian Federation']
# Out:
# socialmedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: socialmedia, dtype: int64

# %%
countrygroup['socialmedia'].value_counts(normalize=True).loc['India']
# Out:
# socialmedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: socialmedia, dtype: float64

# %%
countrygroup['convertedcomp'].median()
# Out:
# country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: convertedcomp, Length: 179, dtype: float64

# %%
countrygroup['convertedcomp'].median().loc['Germany']
# Out:
# 63016.0

# %%
countrygroup['convertedcomp'].agg(['median','mean'])
# Out:
#                                         median           mean
# country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
countrygroup['convertedcomp'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt=df['country']=='India'
df.loc[filt]['languageworkedwith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 77339    False
# 79795     True
# 83862    False
# 84299     True
# 86012    False
# Name: languageworkedwith, Length: 9061, dtype: object

# %%
filt=df['country']=='India'
df.loc[filt]['languageworkedwith'].str.contains('Python').sum()
# Out:
# 3105

# %%
countrygroup['languageworkedwith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [177], line 1
# ----> 1 countrygroup['languageworkedwith'].str.contains('Python').sum()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\groupby\groupby.py:981, in GroupBy.__getattr__(self, attr)
#     978 if attr in self.obj:
#     979     return self[attr]
# --> 981 raise AttributeError(
#     982     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     983 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
countrygroup['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: languageworkedwith, Length: 179, dtype: int64

# %%
country_respondents=df['country'].value_counts()

# %%
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: country, Length: 179, dtype: int64

# %%
countryusespython=countrygroup['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())

# %%
countryusespython
# Out:
# country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: languageworkedwith, Length: 179, dtype: int64

# %%
python_df=pd.concat([country_respondents,countryusespython],axis='columns',sort=False)

# %%
python_df
# Out:
#                    country  languageworkedwith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df=python_df.rename(columns={'country':'Numrespondents','languageworkedwith':'NumKnowsPython'})

# %%
python_df['PctKnowsPython']=(python_df['NumKnowsPython']/python_df['Numrespondents'])*100
python_df
# Out:
#                    Numrespondents  NumKnowsPython  PctKnowsPython
# United States               20949           10083       48.131176
# India                        9061            3105       34.267741
# Germany                      5866            2451       41.783157
# United Kingdom               5737            2384       41.554820
# Canada                       3395            1558       45.891016
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1      100.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.head(50)
# Out:
#                                   Numrespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Niger                                          1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Guinea                                         3               2
# Bahamas                                        3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Haiti                                          5               3
# Benin                                          5               3
# ...

# %%
python_df.loc['Japan']
# Out:
# Numrespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64

# %%
# while creating datframe add na_values= list of values you want to be treated a nan

# %%
df['yearscode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: yearscode, dtype: object

# %%
df['yearscode']=df['yearscode'].astype(float)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Kush Juvekar\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Kush Juvekar\AppData\Local\Temp\ipykernel_3768\2356519545.py", line 1, in <module>
#     df['yearscode']=df['yearscode'].astype(float)
#   File "C:\Users\Kush Juvekar\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py", line 6240, in astype
#     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#   File "C:\Users\Kush Juvekar\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py", line 445, in astype
#     return self.apply(
#   File "C:\Users\Kush Juvekar\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py", line 347, in apply
# ...

# %%
df['yearscode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df=df['yearscode'].replace('Less than 1 year',0,inplace=True)
#df=df['yearscode'].replace('More than 50 years',0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [219], line 1
# ----> 1 df=df['yearscode'].replace('Less than 1 year',0,inplace=True)
#       2 #df=df['yearscode'].replace('More than 50 years',0,inplace=True)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
q=pd.read_csv('ETH_1h.csv')
q.head()
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622

# %%
q.shape
# Out:
# (34497, 8)

# %%
q.loc[0,'Date']
# Out:
# '2020-04-16 00:00:00'

# %%
import pandas as pd
d_parser=lambda x: pd.datetime.strptime(x,"%Y-%m-%d %H:%H:%H")
q=pd.read_csv('ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
#q['Date']=q.to_datetime(q['Date'],format='%Y-%m-%d %H')
# Out:
# C:\Users\Kush Juvekar\AppData\Local\Temp\ipykernel_3768\2206721227.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser=lambda x: pd.datetime.strptime(x,"%Y-%m-%d %H:%H:%H")
# C:\Users\Kush Juvekar\AppData\Local\Temp\ipykernel_3768\2206721227.py:3: FutureWarning:
#         Use pd.to_datetime instead.
#
#   q=pd.read_csv('ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [240], line 3
#       1 import pandas as pd
#       2 d_parser=lambda x: pd.datetime.strptime(x,"%Y-%m-%d %H:%H:%H")
# ----> 3 q=pd.read_csv('ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
#       4 #q['Date']=q.to_datetime(q['Date'],format='%Y-%m-%d %H')
#
# ...

# %%
q['Date']=pd.to_datetime(q['Date'],format='%Y-%m-%d %H')
